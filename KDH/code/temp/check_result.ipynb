# %%
import cv2
import pandas as pd
import matplotlib.pyplot as plt

print(cv2.__version__)
print(pd.__version__)
# Out:
# 4.7.0
# 1.1.5

# %%
image_id = "0000"
image_path = "/opt/ml/dataset/test/"
annotation_path = "/opt/ml/yolov8/yolo_submission.csv"

image = cv2.imread(image_path + image_id + '.jpg')
annotations_raw = pd.read_csv(annotation_path).iloc[int(image_id)]["PredictionString"].split()
annotations = [annotations_raw[i:i + 6] for i in range(0, len(annotations_raw), 6)]

print(annotations)
# Out:
# [['7', '0.9761859774589539', '602.17431640625', '518.158203125', '956.4263916015625', '1024.0'], ['7', '0.9753053188323975', '217.7548828125', '52.5439453125', '454.37506103515625', '471.15032958984375'], ['7', '0.9724741578102112', '119.2783203125', '422.1170349121094', '331.1670227050781', '709.4498291015625'], ['7', '0.9648380875587463', '390.0484313964844', '192.9632110595703', '639.9676513671875', '544.3403930664062'], ['5', '0.9444156885147095', '341.7598876953125', '642.56689453125', '396.250244140625', '725.192626953125'], ['1', '0.942058265209198', '567.9173583984375', '102.96612548828125', '787.8765869140625', '374.0570373535156'], ['7', '0.9419159293174744', '264.6470031738281', '441.5936279296875', '431.3700256347656', '579.5186767578125'], ['7', '0.9204815626144409', '448.1446533203125', '601.7288818359375', '647.2633056640625', '875.142822265625'], ['5', '0.9070401191711426', '244.2070770263672', '683.5225830078125', '301.46307373046875', '748.6029052734375'], ['7', '0.903304934501648', '548.4454345703125', '337.80816650390625', '879.5965576171875', '607.8462524414062'], ['7', '0.8701091408729553', '647.9210205078125', '337.5760498046875', '879.7882080078125', '607.4609375'], ['5', '0.8340436816215515', '321.74346923828125', '549.140625', '468.10870361328125', '745.171630859375'], ['5', '0.7869851589202881', '329.5633544921875', '639.6181640625', '352.78094482421875', '684.243408203125'], ['7', '0.755607008934021', '213.57162475585938', '694.3343505859375', '253.40231323242188', '731.622314453125'], ['6', '0.5709173679351807', '430.93212890625', '466.6141357421875', '603.7855224609375', '683.271240234375'], ['5', '0.537854790687561', '388.3905029296875', '684.0286254882812', '424.53125', '721.5825805664062'], ['7', '0.4803403317928314', '319.6489562988281', '562.960205078125', '404.8700866699219', '619.370849609375'], ['1', '0.4690433144569397', '247.21400451660156', '423.98406982421875', '283.211181640625', '474.13568115234375'], ['7', '0.41307777166366577', '465.1595458984375', '554.7501831054688', '561.591552734375', '657.2684936523438'], ['5', '0.2823316156864166', '359.321533203125', '596.6856079101562', '418.38427734375', '648.5021362304688'], ['5', '0.279634028673172', '431.0190734863281', '466.6612243652344', '608.74658203125', '683.2574462890625'], ['5', '0.2626458406448364', '395.09674072265625', '612.69482421875', '450.71014404296875', '686.370849609375']]

# %%
for annotation in annotations:
    category = int(annotation[0])
    confidence = float(annotation[1])
    bbox = [int(float(s)) for s in annotation[2:]]
    cv2.rectangle(image, (bbox[0], bbox[1]), (bbox[2], bbox[3]), (0, 255, 0), 2)

# %%
plt.imshow(image, interpolation='nearest')
plt.show()
